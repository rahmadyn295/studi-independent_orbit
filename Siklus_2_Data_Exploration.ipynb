# %% [markdown]
# <a href="https://colab.research.google.com/github/rahmadyn295/studi-independent_orbit/blob/main/Siklus_2_Data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Siklus-2 Data Exploration
# Sebelum lanjut, harap:
# 1. Jika menggunakan Jupyter Notebook, silahkan pilih "File" --> "Download" --> "Download .ipynb"
# 2. Jika menggunakan Colab, silahkan pilih "File" --> "Save a copy in drive"

# %% [markdown]
# **Data Exploration** adalah sebuah kegiatan yang bertujuan untuk lebih memahami karakteristik dari data.
#
# Motivasi utama dilakukannya data exploration adalah untuk:
# - Membantu kita untuk memilih tools yang tepat untuk melakukan preprocessing atau dalam melakukan analisis.
# - Mengetahui pola / pattern dari data.
#
#
# Kali ini kita akan melakukan Data Exploration menggunakan Python.

# %% [markdown]
# ![image_2022-09-08_160210145.png](data:image/png;base64,...)

# %%
# Tulis di sini
import numpy as np
import pandas as pd

# %% [markdown]
# Langkah pertama, siapkan data yang sudah kita peroleh dari tahap Data Acquisition.
#
# https://people.sc.fsu.edu/~jburkardt/data/csv/freshman_kgs.csv
#
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
url ='https://people.sc.fsu.edu/~jburkardt/data/csv/freshman_kgs.csv'
df = pd.read_csv(url)
df.head()
# Out:
#   Sex   "Weight (Sep)"   "Weight (Apr)"   "BMI (Sep)"   "BMI (Apr)"
# 0   M               72               59         22.02         18.14
# 1   M               97               86         19.70         17.44
# 2   M               74               69         24.09         22.43
# 3   M               93               88         26.97         25.57
# 4   F               68               64         21.51         20.10

# %% [markdown]
# Jika link di atas tidak bisa, download data [di sini](https://drive.google.com/file/d/14AtRNW4-BuKfJW60ntfaN9IVCasX-GKf/view?usp=sharing).

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Summary Descriptive Statistics
#
# Summary descriptive statistics adalah rangkuman properti dari sebuah data
#
# Properti tersebut adalah berupa:
# - frekuensi,
# - modus,
# - mean,
# - range, dan
# - standar deviasi (deviation standard).

# %% [markdown]
# Tampilkan informasi data menggunakan syntax berikut:
#
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sex              67 non-null     object
#  1    "Weight (Sep)"  67 non-null     int64
#  2    "Weight (Apr)"  67 non-null     int64
#  3    "BMI (Sep)"     67 non-null     float64
#  4    "BMI (Apr)"     67 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.7+ KB

# %% [markdown]
# Berdasarkan informasi yang ditampilkan, data memiliki:
# - 67 baris
# - 5 kolom:
#     - Sex dengan tipe data object/str
#     - Weight (Sep) dengan tipe data int
#     - Weight (Apr) dengan tipe data int
#     - BMI (Sep) dengan tipe data float
#     - BMI (Apr) dengan tipe data float

# %% [markdown]
# ---

# %% [markdown]
# Pada Python, kita tidak perlu membuat program untuk frekuensi, mean, standar deviasi, range, dan kuartil.
#
# Kita hanya perlu memanggil method `describe()`.
#
#
# Method `describe()` secara otomatis menghitung:
# - frekuensi (count)
# - mean
# - median (kuartil 50%)
# - standar deviasi
# - range (nilai min dan max)
# - kuartil
#
# Kolom-kolom yang **datanya numerik**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
df.describe()
# Out:
#         "Weight (Sep)"   "Weight (Apr)"   "BMI (Sep)"   "BMI (Apr)"
# count        67.000000        67.000000     67.000000     67.000000
# mean         65.059701        66.238806     22.030000     22.484179
# std          11.285390        11.284327      3.308901      3.602527
# min          42.000000        47.000000     15.080000     16.890000
# 25%          56.500000        58.000000     19.965000     20.230000
# 50%          64.000000        66.000000     21.730000     22.310000
# 75%          70.500000        70.000000     23.160000     23.860000
# max          97.000000       105.000000     36.570000     40.860000

# %% [markdown]
# Coba simpulkan hasil `describe()` di atas!

# %% [markdown]
# ---

# %% [markdown]
# Selain membuat deskripsi kolom numerik, kita juga bisa membuat deskripsi kolom kategorik dengan menambahkan argumen `include='all'` pada `describe()`.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
df.describe(include='object')
# Out:
#        Sex
# count   67
# unique   2
# top      F
# freq    35

# %% [markdown]
# Coba simpulkan hasil `describe(include='object')` di atas!

# %% [markdown]
# ## Data Visualization
#
# Data Visualization (visualisasi data) adalah tampilan berupa grafis atau visual dari informasi dan data.
#
# Dalam kata lain, data visualization mengubah kumpulan data menjadi hal lebih sederhana untuk ditampilkan.
#
# Dengan menggunakan elemen visual tersebut, pembaca akan lebih mudah memahami tren, pola, dan outliers dalam suatu data.
#
# Pada Python, terdapat dua library yang umum digunakan untuk membuat Data Visualization, yakni:
# 1. [Matplotlib](https://matplotlib.org/stable/index.html)
# 2. [Seaborn](https://seaborn.pydata.org/)

# %% [markdown]
# ### Visualisasi Data Menggunakan Library Matplotlib

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1. Bar Graph atau Bar Chart
#
# Biasa digunakan untuk membandingkan kategori.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# menghitung jumlah pria dan wanita
jumlah_pria = df['Sex'].value_counts()['M']
jumlah_wanita = df['Sex'].value_counts()['F']

#Membuat Bar Chart
plt.bar(['Pria','Wanita'], [jumlah_pria,jumlah_wanita])
plt.show()

# %% [markdown]
# Kita dapat mengubah ukuran dan menambah keterangan lain dalam plot, seperti:
# - Judul plot
# - Nama sumbu x
# - Nama sumbu y
# - Warna Bar Chart

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
plt.figure(figsize=(5,3))
plt.bar(['Pria','Wanita'], [jumlah_pria,jumlah_wanita], color=['blue','orange'])
plt.title('Perbandingan Jumlah Wanita dan Pria')
plt.xlabel('jenis kelamin')
plt.ylabel('jumlah')
plt.show()

# %% [markdown]
# Contoh bar graph/chart lainnya:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#menghitung rata rata berat pria dan wanita bulan september
rata2berat_pria = df[df['Sex']=='M'][' "Weight (Sep)"'].mean()
rata2berat_wanita = df[df['Sex']=='F'][' "Weight (Sep)"'].mean()
weights = [rata2berat_pria,rata2berat_wanita]
labels = ['pria','wanita']

#membuat bar graph
plt.figure(figsize=(7,5))
plt.bar(labels, weights)
plt.title('Perbandingan rata rata berat badan Wanita dan Pria bulan september')
plt.show()

# %% [markdown]
# #### 2. Histogram
#
# Biasa digunakan untuk menampilkan distribusi frekuensi.

# %% [markdown]
# Jalankan program berikut kemudian simpulkan plot-nya!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
plt.hist(df[' "Weight (Sep)"'])#histogram
plt.title('Histogram Berat Badan (Sep)')
plt.xlabel('Frekuensi')
plt.ylabel('Berat')
plt.show()

# %% [markdown]
# Cara lain dalam membuat histogram:
#
# Jalankan program lalu simpulkan plot-nya!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
df[' "Weight (Apr)"'].plot(kind='hist', figsize=(7,5))
plt.title('Histogram Berat Badan (Sep)')
plt.xlabel('Frekuensi')
plt.ylabel('Berat')
plt.show()

# %% [markdown]
# Apa perbedaan antara bar graph dan histogram?

# %% [markdown]
# #### 3. Line Chart
#
# Biasa digunakan untuk menunjukkan tren pada data atau membandingkan data.

# %% [markdown]
# Contoh line chart:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
bmi_april = df[' "BMI (Sep)"']

plt.plot(bmi_april)
plt.title('BMI bulan September')
plt.xlabel('Peserta')
plt.ylabel('BMI')
plt.show()

# %% [markdown]
# Contoh line chart untuk membandingkan data:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
weight_sep =df[' "Weight (Sep)"']
bmi_sep =df[' "BMI (Sep)"']

plt.plot(weight_sep)
plt.plot(bmi_sep)
plt.title('BMI bulan September',fontsize=10)
plt.xlabel('Peserta', fontsize=10)
plt.ylabel('Nilai',fontsize=10)
plt.show()

# %% [markdown]
# Kita dapat menambahkan legenda dalam plot.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
weight_sep =df[' "Weight (Sep)"']
bmi_sep =df[' "BMI (Sep)"']

plt.plot(weight_sep, label ='Berat Bulan September')
plt.plot(bmi_sep, label='BMI bulan september')
plt.title('BMI bulan September',fontsize=10)
plt.xlabel('Peserta', fontsize=10)
plt.ylabel('Nilai',fontsize=10)
plt.legend()
plt.show()

# %% [markdown]
# Kita juga dapat mengubah bentuk dan warna garis dalam plot:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
weight_sep =df[' "Weight (Sep)"']
bmi_sep =df[' "BMI (Sep)"']

plt.plot(weight_sep,'o--', label ='Berat Bulan September')
plt.plot(bmi_sep,'r--', label='BMI bulan september')
plt.title('BMI bulan September',fontsize=10)
plt.xlabel('Peserta', fontsize=10)
plt.ylabel('Nilai',fontsize=10)
plt.legend()
plt.show()

# %% [markdown]
# Cara lain dalam membuat line chart:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
df[[' "BMI (Apr)"',' "BMI (Sep)"']].plot(kind='line',figsize=(10,5))
plt.title('Perbandinga BMI bulan April dan September',fontsize=10)
plt.xlabel('Peserta', fontsize=10)
plt.ylabel('BMI',fontsize=10)
plt.legend()
plt.show()

# %% [markdown]
# #### 4. Scatter plot
#
# Menyajikan hubungan antara dua variabel dalam kumpulan data.

# %% [markdown]
# Contohnya menampilkan hubungan antara Berat dan BMI bulan April:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
berat_apr =df[' "Weight (Apr)"']
bmi_apr =df[' "BMI (Apr)"']


plt.scatter(berat_apr,bmi_apr)
plt.title('Hubungan Berat dan BMI bulan April')
plt.xlabel('Berat', fontsize=10)
plt.ylabel('BMI',fontsize=10)
plt.show()

# %% [markdown]
# Contoh lain dalam membuat scatter plot:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
df[[' "Weight (Apr)"',' "Weight (Sep)"']].plot(kind='scatter',x=' "Weight (Sep)"',y=' "Weight (Apr)"', figsize=(10,6), color='red')
plt.title('Hubungan Berat bulan April dan September')
plt.xlabel('September', fontsize=10)
plt.ylabel('April',fontsize=10)
plt.show()

# %% [markdown]
# Scatter plotnya seperti membentuk garis lurus serong kanan. Artinya, hubungan berat badan bulan April dan September erat dan positif.

# %% [markdown]
# #### 5. Pie Chart
#
# Menunjukkan proporsi relasional antara data.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
jumlah_pria = df['Sex'].value_counts()['M']
jumlah_wanita = df['Sex'].value_counts()['F']
counts = [jumlah_pria,jumlah_wanita]
labels = ['pria','wanita']
colors = ['lightblue','pink']

#Membuat Bar Chart
plt.figure(figsize=(7,5))
plt.pie(counts, labels=labels, colors=colors, autopct='%.2f')
plt.title('Perbandingan Jumlah Wanita dan Pria')
plt.show()

# %% [markdown]
# Bandingkan tampilan bar chart dan pie chart!
#
# Manakah yang lebih baik dalam menampilkan perbandingan jumlah pria dan wanita?

# %% [markdown]
# ### Visualisasi Data Menggunakan Library Seaborn

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
import seaborn as sns

# %% [markdown]
# #### 1. Line Chart

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
sns.lineplot(data=df[[' "Weight (Sep)"',' "BMI (Sep)"']])
# Out:
# <Axes: >

# %% [markdown]
# #### 2. Scatter Plot

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
sns.relplot(x= ' "Weight (Sep)"',y= ' "BMI (Sep)"',data=df)

# %% [markdown]
# Scatter plotnya seperti membentuk garis lurus serong kanan, artinya hubungan berat badan bulan april dan september erat dan positif.

# %% [markdown]
# #### 3. Histogram

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
sns.displot(data=df, x=' "Weight (Sep)"', hue="Sex",kde=True)

# %% [markdown]
# Terlihat histogram kategori laki-laki dan perempuan

# %% [markdown]
# #### 4. Box Plot

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
sns.boxplot(data=df, x=' "Weight (Sep)"')
# Out:
# <Axes: xlabel=' "Weight (Sep)"'>

# %% [markdown]
# Terlihat ada outlier di bagian atas box plot (bagian kanan).

# %% [markdown]
# #### 5. Cat Plot (Category Plot)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tulis di sini
sns.catplot(data=df,x="Sex",y=' "Weight (Sep)"')

# %% [markdown]
# Sebaran data berat badan bulan april per kategori laki-laki dan perempuan

# %% [markdown]
# #### 6. Heatmap (Korelasi)
#
# ![heatmap.PNG](data:image/png;base64,...)

# %%
# Tulis di sini
corrmat=df.corr()
plt.figure(figsize=(10,7))
sns.heatmap(corrmat, annot=True)
# Out:
# <ipython-input-29-38260d371bce>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat=df.corr()
# <Axes: >

# %% [markdown]
# Warna merepresentasikan keeratan hubungan:
# - bisa diliat dari nilai hubungan/korelasinya.
# - bisa dilihat dari penggaris di sebelah heatmap.

# %% [markdown]
# ---

# %% [markdown]
# Apa perbedaan antara library Matplotlib dan Seaborn?

# %% [markdown]
# # Exercise (Latihan)

# %% [markdown]
# Gunakan data dari: https://people.sc.fsu.edu/~jburkardt/data/csv/cities.csv
#
# Jika link mati, download data [di sini](https://drive.google.com/file/d/14GcTF9cl7Rl7M8doQ0BJQfmLTU29AsPj/view?usp=sharing).
#
# Buatlah:
# - Summary Descriptive Statistics
# - Kesimpulan Summary Descriptive Statistics tersebut
# - Beberapa visualisasi data
# - Kesimpulan visualisasi data tersebut
#
# Kumpulkan program kepada HC!

# %% [markdown]
# # Summary Descriptive Statistics

# %%
url ='https://people.sc.fsu.edu/~jburkardt/data/csv/cities.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0    41        5       59   "N"       80       39        0   "W"
# 1    42       52       48   "N"       97       23       23   "W"
# 2    46       35       59   "N"      120       30       36   "W"
# 3    42       16       12   "N"       71       48        0   "W"
# 4    43       37       48   "N"       89       46       11   "W"
#
#                "City"  "State"
# 0        "Youngstown"       OH
# 1           "Yankton"       SD
# 2            "Yakima"       WA
# 3         "Worcester"       MA
# 4   "Wisconsin Dells"       WI

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LatD      128 non-null    int64
#  1    "LatM"   128 non-null    int64
#  2    "LatS"   128 non-null    int64
#  3    "NS"     128 non-null    object
#  4    "LonD"   128 non-null    int64
#  5    "LonM"   128 non-null    int64
#  6    "LonS"   128 non-null    int64
#  7    "EW"     128 non-null    object
#  8    "City"   128 non-null    object
#  9    "State"  128 non-null    object
# dtypes: int64(6), object(4)
# memory usage: 10.1+ KB

# %%
df.describe()
# Out:
#              LatD      "LatM"      "LatS"      "LonD"      "LonM"      "LonS"
# count  128.000000  128.000000  128.000000  128.000000  128.000000  128.000000
# mean    38.820312   30.765625   27.492188   93.250000   27.742188   26.960938
# std      5.200596   16.426158   18.977814   15.466499   16.927937   18.727807
# min     26.000000    1.000000    0.000000   71.000000    0.000000    0.000000
# 25%     35.000000   16.000000   11.000000   80.000000   14.000000   11.000000
# 50%     39.000000   31.000000   24.000000   89.500000   26.500000   23.500000
# 75%     42.250000   45.000000   47.000000  103.250000   40.250000   47.000000
# max     50.000000   59.000000   59.000000  123.000000   58.000000   59.000000

# %% [markdown]
# Kesimpulan Summary Descriptive Statistics diatas adalah
# Dari Summary Descriptive Statistics di atas, kita bisa membuat kesimpulan sebagai berikut:
#
# 1. Frekuensi (count): Data terdiri dari 128 observasi.
# 2. Mean: Rata-rata dari "LatD" adalah sekitar 38.82, "LatM" adalah sekitar 30.77, "LatS" adalah sekitar 27.49, "LonD" adalah sekitar 93.25, "LonM" adalah sekitar 27.74, dan "LonS" adalah sekitar 26.96.
# 3. Median (kuartil 50%): Nilai tengah dari "LatD" adalah 39, "LatM" adalah 31, "LatS" adalah 24, "LonD" adalah 89.5, "LonM" adalah 26.5, dan "LonS" adalah 23.5.
# 4. Standar deviasi: "LatD" memiliki standar deviasi sekitar 5.20, "LatM" sekitar 16.43, "LatS" sekitar 18.98, "LonD" sekitar 15.47, "LonM" sekitar 16.93, dan "LonS" sekitar 18.73.
# 5. Range (nilai min dan max): Rentang "LatD" adalah antara 26 hingga 50, "LatM" antara 1 hingga 59, "LatS" antara 0 hingga 59, "LonD" antara 71 hingga 123, "LonM" antara 0 hingga 58, dan "LonS" antara 0 hingga 59.
# 6. Kuartil: Kuartil pertama (25%) dari "LatD" adalah 35, "LatM" adalah 16, "LatS" adalah 11, "LonD" adalah 80, "LonM" adalah 14, dan "LonS" adalah 11. Kuartil ketiga (75%) dari "LatD" adalah 42.25, "LatM" adalah 45, "LatS" adalah 47, "LonD" adalah 103.25, "LonM" adalah 40.25, dan "LonS" adalah 47.
#
# Kesimpulannya, data ini menggambarkan informasi tentang data lokasi geografis dengan koordinat lintang dan bujur dalam derajat, menit, dan detik. Data ini memiliki variasi yang cukup besar dalam nilai-nilainya.

# %% [markdown]
# # Visualisasi Data

# %%
Lat_M = df[' "LatM"']

plt.plot(Lat_M)
plt.show()

# %%
latm =df[' "LatM"']
lats =df[' "LatS"']


plt.scatter(latm,lats)
plt.xlabel('LatM', fontsize=10)
plt.ylabel('LatS',fontsize=10)
plt.show()

# %% [markdown]
# 1. Terdapat hubungan positif yang kuat antara Lats dan LatM. Hal ini terlihat dari pola sebaran titik-titik pada grafik yang membentuk garis lurus dengan kemiringan positif.
# 2. Semakin tinggi nilai Lats, semakin tinggi pula nilai LatM. Hal ini menunjukkan bahwa Lats merupakan faktor penentu utama LatM.
# 3. Terdapat beberapa titik yang berada di luar garis tren. Hal ini menunjukkan bahwa terdapat beberapa faktor lain yang memengaruhi LatM selain Lats.
